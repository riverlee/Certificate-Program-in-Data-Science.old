# %% [markdown]
# # Exploratory data analysis
#
# - data url: https://www.drivendata.org/competitions/7/pump-it-up-data-mining-the-water-table/
#
# ## Import packages and load data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

d = pd.read_csv("../data/train.csv")
d.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#            ...          payment_type water_quality quality_group  \
# 0          ...              annually          soft          good
# 1          ...             never pay          soft          good
# 2          ...            per bucket          soft          good
# 3          ...             never pay          soft          good
# 4          ...             never pay          soft          good
#
#        quantity  quantity_group                source           source_type  \
# 0        enough          enough                spring                spring
# 1  insufficient    insufficient  rainwater harvesting  rainwater harvesting
# 2        enough          enough                   dam                   dam
# 3           dry             dry           machine dbh              borehole
# 4      seasonal        seasonal  rainwater harvesting  rainwater harvesting
#
#    source_class              waterpoint_type waterpoint_type_group
# 0   groundwater           communal standpipe    communal standpipe
# 1       surface           communal standpipe    communal standpipe
# 2       surface  communal standpipe multiple    communal standpipe
# 3   groundwater  communal standpipe multiple    communal standpipe
# 4       surface           communal standpipe    communal standpipe
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Character features
#
# ### To do list
#
# - For each of the character features, look at the number of unique values
# - For each of the character features, look at the missing values
#
# ### Actions on the findings
#
# - **recorded_by** is the same for all the samples, <font color='red'>need to be removed</font>
# - **wpt_name,subvillage,scheme_name,installer,ward,funder** has unique values >1000, <font color='red'>need to further re-group them</font>
# - Take 0 as missing value (NA) for funder and installer features, update data by setting 0 to NA
# - **scheme_name** has 47.418% samples with missing value, need to be removed

# %% [markdown]
# #### look at the number of unique values

# %%
## subset of the train dataset whose datatype is object(string)
character_features_df = d.loc[:, d.dtypes == object]
print(character_features_df.dtypes)
character_features_df.head()
# Out:
# date_recorded            object
# funder                   object
# installer                object
# wpt_name                 object
# basin                    object
# subvillage               object
# region                   object
# lga                      object
# ward                     object
# public_meeting           object
# recorded_by              object
# scheme_management        object
# scheme_name              object
# permit                   object
# extraction_type          object
# extraction_type_group    object
# extraction_type_class    object
# management               object
# management_group         object
# payment                  object
# payment_type             object
# water_quality            object
# quality_group            object
# quantity                 object
# quantity_group           object
# source                   object
# source_type              object
# source_class             object
# waterpoint_type          object
# waterpoint_type_group    object
# dtype: object
#   date_recorded        funder     installer              wpt_name  \
# 0    2011-03-14         Roman         Roman                  none
# 1    2013-03-06       Grumeti       GRUMETI              Zahanati
# 2    2013-02-25  Lottery Club  World vision           Kwa Mahundi
# 3    2013-01-28        Unicef        UNICEF  Zahanati Ya Nanyumbu
# 4    2011-07-13   Action In A       Artisan               Shuleni
#
#                      basin  subvillage   region        lga        ward  \
# 0               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi
# 1            Lake Victoria     Nyamara     Mara  Serengeti       Natta
# 2                  Pangani     Majengo  Manyara  Simanjiro     Ngorika
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu
# 4            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi
#
#   public_meeting          ...          payment_type water_quality  \
# 0           True          ...              annually          soft
# 1            NaN          ...             never pay          soft
# 2           True          ...            per bucket          soft
# 3           True          ...             never pay          soft
# 4           True          ...             never pay          soft
#
#   quality_group      quantity quantity_group                source  \
# 0          good        enough         enough                spring
# 1          good  insufficient   insufficient  rainwater harvesting
# 2          good        enough         enough                   dam
# 3          good           dry            dry           machine dbh
# 4          good      seasonal       seasonal  rainwater harvesting
#
#             source_type source_class              waterpoint_type  \
# 0                spring  groundwater           communal standpipe
# 1  rainwater harvesting      surface           communal standpipe
# 2                   dam      surface  communal standpipe multiple
# 3              borehole  groundwater  communal standpipe multiple
# 4  rainwater harvesting      surface           communal standpipe
#
#   waterpoint_type_group
# 0    communal standpipe
# 1    communal standpipe
# 2    communal standpipe
# 3    communal standpipe
# 4    communal standpipe
#
# [5 rows x 30 columns]

# %%
## Get unique values for each character features
charF_nunique = character_features_df.apply(pd.Series.nunique)
## charF_nunique
aa  = pd.DataFrame({"feature":charF_nunique.index,"number":charF_nunique})
aa = aa.sort_values("number")
aa
# Out:
#                                      feature  number
# recorded_by                      recorded_by       1
# public_meeting                public_meeting       2
# permit                                permit       2
# source_class                    source_class       3
# management_group            management_group       5
# quantity_group                quantity_group       5
# quantity                            quantity       5
# waterpoint_type_group  waterpoint_type_group       6
# quality_group                  quality_group       6
# payment_type                    payment_type       7
# source_type                      source_type       7
# waterpoint_type              waterpoint_type       7
# extraction_type_class  extraction_type_class       7
# payment                              payment       7
# water_quality                  water_quality       8
# basin                                  basin       9
# source                                source      10
# scheme_management          scheme_management      12
# management                        management      12
# extraction_type_group  extraction_type_group      13
# extraction_type              extraction_type      18
# region                                region      21
# lga                                      lga     125
# date_recorded                  date_recorded     356
# funder                                funder    1897
# ward                                    ward    2092
# installer                          installer    2145
# scheme_name                      scheme_name    2696
# subvillage                        subvillage   19287
# wpt_name                            wpt_name   37400

# %%
## Barplot it
ax = aa.plot(kind="bar",logy=True,figsize=(12,8)) 
ax.figure
ax.set_xlabel('Character Features')
ax.set_ylabel('Number of unique values(log scaled)')
ax.set_title('Number of unique values for character features')

for idx, label in enumerate(list(aa.index)): 
    acc = "number"
    value = np.round(aa.iloc[idx][acc],decimals=2)
    ax.annotate(value,(idx, value),
                         xytext=(-2, 0), 
                         textcoords='offset points')

# %% [markdown]
# #### For each of the character features, look at the missing values

# %%
### Look at missing values
### Missing value could be NA or 0 or -
f=character_features_df.loc[:,"funder"]
character_features_df.loc[f=="0",:]
# Out:
#       date_recorded funder installer                       wpt_name  \
# 145      2013-03-21      0         0                       Chekanao
# 152      2013-03-16      0         0                      Msikitini
# 393      2013-03-18      0         0                   Kwa Chambuso
# 417      2013-03-22      0         0                     Ccm Kivule
# 428      2013-03-12      0         0                  Ofisi Ya Kata
# 503      2013-03-18      0         0                        Shuleni
# 567      2013-03-18      0         0                           none
# 636      2013-03-14      0         0                       Kwa Weso
# 702      2013-03-19      0         0                  Kwa Mzee Iddy
# 57469      Kitunda            NaN          ...            per bucket
# 57499      Kimbiji           True          ...            per bucket
# 57566         Pugu            NaN          ...            per bucket
# 57744  Pemba Mnazi           True          ...             never pay
# 57780     Msongola           True          ...             never pay
# 57867    Somangira           True          ...             never pay
# 57904     Msongola            NaN          ...            per bucket
# 57906      Chanika            NaN          ...            per bucket
# 58048  Pemba Mnazi           True          ...             never pay
# 58083         Goba           True          ...            per bucket
# 58279  Pemba Mnazi           True          ...             never pay
# 58494      Chanika            NaN          ...            per bucket
# 58564    Vijibweni           True          ...            per bucket
# 58582      Chanika            NaN          ...            per bucket
# 58701      Chanika            NaN          ...             never pay
# 58718         Goba           True          ...            per bucket
# 58795    Vijibweni           True          ...            per bucket
# 58928      Kitunda            NaN          ...            per bucket
# 58938  Pemba Mnazi           True          ...             never pay
# 58965     Msongola           True          ...            per bucket
# 58985         Goba           True          ...            per bucket
# 59001    Mji Mwema           True          ...            per bucket
# 59020      Kitunda            NaN          ...            per bucket
# 59197        Bunju           True          ...            per bucket
# 59237         Pugu            NaN          ...            per bucket
# 59243      Kimbiji           True          ...            per bucket
# 59276      Kitunda            NaN          ...            per bucket
# 59351  Pemba Mnazi           True          ...            per bucket
# 59387     Msongola            NaN          ...            per bucket
#
#          water_quality quality_group      quantity quantity_group  \
# 145               soft          good        enough         enough
# 152              salty         salty           dry            dry
# 393            unknown       unknown       unknown        unknown
# 417               soft          good        enough         enough
# 428            unknown       unknown           dry            dry
# 503              salty         salty           dry            dry
# 567    salty abandoned         salty        enough         enough
# 636              salty         salty           dry            dry
# 702               soft          good        enough         enough
# 797            unknown       unknown       unknown        unknown
# 840              salty         salty        enough         enough
# 849               soft          good        enough         enough
# 857               soft          good        enough         enough
# 1040              soft          good  insufficient   insufficient
# 1044              soft          good        enough         enough
# 1068              soft          good        enough         enough
# 1070              soft          good        enough         enough
# 1360             salty         salty        enough         enough
# 1440              soft          good        enough         enough
# 1453              soft          good           dry            dry
# 1522              soft          good        enough         enough
# 1559              soft          good        enough         enough
# 1657              soft          good        enough         enough
# 1675             salty         salty           dry            dry
# 1868              soft          good        enough         enough
# 2194              soft          good        enough         enough
# 2226              soft          good        enough         enough
# 2413              soft          good        enough         enough
# 2434              soft          good        enough         enough
# 2548              soft          good           dry            dry
# ...                ...           ...           ...            ...
# 57226             soft          good        enough         enough
# 57469             soft          good        enough         enough
# 57499            salty         salty        enough         enough
# 57566  salty abandoned         salty        enough         enough
# 57744             soft          good           dry            dry
# 57780             soft          good        enough         enough
# 57867            salty         salty           dry            dry
# 57904             soft          good        enough         enough
# 57906  salty abandoned         salty        enough         enough
# 58048            salty         salty           dry            dry
# 58083            salty         salty           dry            dry
# 58279             soft          good        enough         enough
# 58494             soft          good        enough         enough
# 58564             soft          good           dry            dry
# 58582            salty         salty        enough         enough
# 58701  salty abandoned         salty        enough         enough
# 58718             soft          good           dry            dry
# 58795             soft          good           dry            dry
# 58928             soft          good        enough         enough
# 58938             soft          good  insufficient   insufficient
# 58965             soft          good  insufficient   insufficient
# 58985             soft          good  insufficient   insufficient
# 59001            salty         salty        enough         enough
# 59020             soft          good        enough         enough
# 59197             soft          good        enough         enough
# 59237  salty abandoned         salty  insufficient   insufficient
# 59243             soft          good        enough         enough
# 59276             soft          good        enough         enough
# 59351             soft          good        enough         enough
# 59387             soft          good        enough         enough
#
#              source   source_type source_class     waterpoint_type  \
# 145     machine dbh      borehole  groundwater  communal standpipe
# 152     machine dbh      borehole  groundwater               other
# 393     machine dbh      borehole  groundwater               other
# 417     machine dbh      borehole  groundwater  communal standpipe
# 428    shallow well  shallow well  groundwater               other
# 503     machine dbh      borehole  groundwater               other
# 567     machine dbh      borehole  groundwater  communal standpipe
# 636     machine dbh      borehole  groundwater  communal standpipe
# 702     machine dbh      borehole  groundwater  communal standpipe
# 797    shallow well  shallow well  groundwater               other
# 840     machine dbh      borehole  groundwater  communal standpipe
# 849     machine dbh      borehole  groundwater  communal standpipe
# 857     machine dbh      borehole  groundwater           hand pump
# 1040          river    river/lake      surface  communal standpipe
# 1044   shallow well  shallow well  groundwater           hand pump
# 1068   shallow well  shallow well  groundwater  communal standpipe
# 1070    machine dbh      borehole  groundwater  communal standpipe
# 1360    machine dbh      borehole  groundwater  communal standpipe
# 1440   shallow well  shallow well  groundwater           hand pump
# 1453          river    river/lake      surface  communal standpipe
# 1522          river    river/lake      surface  communal standpipe
# 1559    machine dbh      borehole  groundwater  communal standpipe
# 1657    machine dbh      borehole  groundwater  communal standpipe
# 1675    machine dbh      borehole  groundwater               other
# 1868       hand dtw      borehole  groundwater  communal standpipe
# 2194    machine dbh      borehole  groundwater  communal standpipe
# 2226    machine dbh      borehole  groundwater  communal standpipe
# 2413    machine dbh      borehole  groundwater  communal standpipe
# 2434    machine dbh      borehole  groundwater  communal standpipe
# 2548          river    river/lake      surface  communal standpipe
# ...             ...           ...          ...                 ...
# 57226   machine dbh      borehole  groundwater  communal standpipe
# 57469   machine dbh      borehole  groundwater  communal standpipe
# 57499   machine dbh      borehole  groundwater  communal standpipe
# 57566   machine dbh      borehole  groundwater           hand pump
# 57744   machine dbh      borehole  groundwater               other
# 57780  shallow well  shallow well  groundwater               other
# 57867   machine dbh      borehole  groundwater  communal standpipe
# 57904   machine dbh      borehole  groundwater  communal standpipe
# 57906   machine dbh      borehole  groundwater  communal standpipe
# 58048   machine dbh      borehole  groundwater           hand pump
# 58083      hand dtw      borehole  groundwater           hand pump
# 58279   machine dbh      borehole  groundwater           hand pump
# 58494  shallow well  shallow well  groundwater  communal standpipe
# 58564   machine dbh      borehole  groundwater  communal standpipe
# 58582      hand dtw      borehole  groundwater  communal standpipe
# 58701   machine dbh      borehole  groundwater  communal standpipe
# 58718         river    river/lake      surface  communal standpipe
# 58795   machine dbh      borehole  groundwater               other
# 58928   machine dbh      borehole  groundwater  communal standpipe
# 58938  shallow well  shallow well  groundwater           hand pump
# 58965   machine dbh      borehole  groundwater  communal standpipe
# 58985         river    river/lake      surface  communal standpipe
# 59001   machine dbh      borehole  groundwater  communal standpipe
# 59020   machine dbh      borehole  groundwater  communal standpipe
# 59197         river    river/lake      surface  communal standpipe
# 59237   machine dbh      borehole  groundwater  communal standpipe
# 59243  shallow well  shallow well  groundwater           hand pump
# 59276   machine dbh      borehole  groundwater  communal standpipe
# 59351   machine dbh      borehole  groundwater  communal standpipe
# 59387   machine dbh      borehole  groundwater  communal standpipe
#
#       waterpoint_type_group
# 145      communal standpipe
# 152                   other
# 393                   other
# 417      communal standpipe
# 428                   other
# 503                   other
# 567      communal standpipe
# 636      communal standpipe
# 702      communal standpipe
# 797                   other
# 840      communal standpipe
# 849      communal standpipe
# 857               hand pump
# 1040     communal standpipe
# 1044              hand pump
# 1068     communal standpipe
# 1070     communal standpipe
# 1360     communal standpipe
# 1440              hand pump
# 1453     communal standpipe
# 1522     communal standpipe
# 1559     communal standpipe
# 1657     communal standpipe
# 1675                  other
# 1868     communal standpipe
# 2194     communal standpipe
# 2226     communal standpipe
# 2413     communal standpipe
# 2434     communal standpipe
# 2548     communal standpipe
# ...                     ...
# 57226    communal standpipe
# 57469    communal standpipe
# 57499    communal standpipe
# 57566             hand pump
# 57744                 other
# 57780                 other
# 57867    communal standpipe
# 57904    communal standpipe
# 57906    communal standpipe
# 58048             hand pump
# 58083             hand pump
# 58279             hand pump
# 58494    communal standpipe
# 58564    communal standpipe
# 58582    communal standpipe
# 58701    communal standpipe
# 58718    communal standpipe
# 58795                 other
# 58928    communal standpipe
# 58938             hand pump
# 58965    communal standpipe
# 58985    communal standpipe
# 59001    communal standpipe
# 59020    communal standpipe
# 59197    communal standpipe
# 59237    communal standpipe
# 59243             hand pump
# 59276    communal standpipe
# 59351    communal standpipe
# 59387    communal standpipe
#
# [777 rows x 30 columns]

# %%
### see which character features has 0
(character_features_df == "0").sum()
# Out:
# date_recorded              0
# funder                   777
# installer                777
# wpt_name                   0
# basin                      0
# subvillage                 0
# region                     0
# lga                        0
# ward                       0
# public_meeting             0
# recorded_by                0
# scheme_management          0
# scheme_name                0
# permit                     0
# extraction_type            0
# extraction_type_group      0
# extraction_type_class      0
# management                 0
# management_group           0
# payment                    0
# payment_type               0
# water_quality              0
# quality_group              0
# quantity                   0
# quantity_group             0
# source                     0
# source_type                0
# source_class               0
# waterpoint_type            0
# waterpoint_type_group      0
# dtype: int64

# %%
(character_features_df == "-").sum()
# Out:
# date_recorded            0
# funder                   0
# installer                3
# wpt_name                 0
# basin                    0
# subvillage               0
# region                   0
# lga                      0
# ward                     0
# public_meeting           0
# recorded_by              0
# scheme_management        0
# scheme_name              0
# permit                   0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# quantity_group           0
# source                   0
# source_type              0
# source_class             0
# waterpoint_type          0
# waterpoint_type_group    0
# dtype: int64
